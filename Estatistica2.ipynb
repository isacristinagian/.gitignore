# %% [markdown]
# <a href="https://colab.research.google.com/github/isacristinagian/.gitignore/blob/main/Estatistica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Estudo para demonstrar a correlação entre ações que pagam dividendos e respectivas valorizações na bolsa de valores.

# %% [markdown]
# A regressão linear é um algoritmo de aprendizado de máquina baseado em aprendizado supervisionado.Usado para interpretar relaçao entre variáveis numéricas e previsão.

# %% [markdown]
# Gerando arquivo com dados Nasdaq e Bovespa.

# %%
dados = pd.read_excel('/dividendos.xlsx')
dados.shape
# Out:
# (168, 5)

# %%
dados.head()
# Out:
#    Ações  Preco_Atual  Dividendos    Upside        DY
# 0  AGRO3        26.35    0.668270  0.227135  0.025361
# 1  AGXY3         1.48    0.000000  0.000000  0.000000
# 2  JALL3         6.79    0.421119  0.870398  0.062021
# 3  RAIZ4         3.25    0.226255 -0.846154  0.069617
# 4  SLCE3        18.20    1.342706  0.769231  0.073775

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ações        168 non-null    object
#  1   Preco_Atual  168 non-null    float64
#  2   Dividendos   168 non-null    float64
#  3   Upside       168 non-null    float64
#  4   DY           168 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 6.7+ KB

# %%
print(dados.dtypes)
# Out:
# Ações           object
# Preco_Atual    float64
# Dividendos     float64
# Upside         float64
# DY             float64
# dtype: object

# %%
from types import TracebackType
from numpy import dtypes

# %% [markdown]
# Verificar se há uma correlação entre os valores dos preços atuais das ações e o upside (potencial de valorização do ativo no mercado financeiro), com base nesta amostra, utilizando Coeficiente de Pearson:

# %%
plt.scatter(dados.Dividendos, dados.Preco_Atual, c='green', label='Dividendos')
plt.scatter(dados.Upside, dados.Preco_Atual,c="brown", label='Upside')
plt.legend()

# %%
np.corrcoef(dados.Dividendos, dados.Preco_Atual)
# Out:
# array([[1.        , 0.46283566],
#        [0.46283566, 1.        ]])

# %% [markdown]
# A correlação é positiva e moderada: empresas que pagam dividendos tem valorização dos preços das ações e vice-versa, conforme esta amostra.

# %% [markdown]
# Carregamento de dados e visualização dos dados estatísticos

# %% [markdown]
# Indice Nasdaq 2024

# %%
base = pd.read_excel('/HistoricalData.xlsx')
base.shape
# Out:
# (21, 5)

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Data    21 non-null     datetime64[ns]
#  1   Open    21 non-null     float64
#  2   High    21 non-null     float64
#  3   Low     21 non-null     float64
#  4   Close   21 non-null     float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 972.0 bytes

# %%
base['Data'] = pd.to_datetime(base['Data'])

# %%
base.describe()
# Out:
#                                 Data          Open          High  \
# count                             21     21.000000     21.000000
# mean   2024-08-02 18:17:08.571428608  18923.577143  19142.824286
# min              2024-07-19 00:00:00  17729.140000  18186.110000
# 25%              2024-07-26 00:00:00  18533.360000  18675.730000
# 50%              2024-08-02 00:00:00  18995.970000  19189.350000
# 75%              2024-08-09 00:00:00  19514.180000  19591.230000
# max              2024-08-16 00:00:00  19794.970000  19933.220000
# std                              NaN    606.966832    532.636233
#
#                 Low         Close
# count     21.000000     21.000000
# mean   18673.423810  18910.378095
# min    17249.300000  17876.510000
# 25%    18288.860000  18514.470000
# 50%    18745.520000  19014.510000
# 75%    19020.440000  19375.050000
# max    19712.030000  19836.540000
# std      636.303402    571.358703

# %%
base.dropna()
# Out:
#          Data      Open      High       Low     Close
# 0  2024-08-16  19514.18  19596.61  19362.94  19515.72
# 1  2024-08-15  19023.65  19515.75  19020.44  19497.78
# 2  2024-08-14  19025.90  19116.99  18839.74  19023.01
# 3  2024-08-13  18565.14  19022.75  18548.17  19014.51
# 4  2024-08-12  18533.36  18675.73  18435.55  18554.76
# 5  2024-08-09  18489.96  18579.67  18288.86  18514.47
# 6  2024-08-08  17729.14  18459.27  17727.64  18420.09
# 7  2024-08-07  17964.55  18458.97  17853.53  17876.51
# 8  2024-08-06  18167.97  18381.61  17859.69  18069.43
# 9  2024-08-05  18151.28  18186.11  17249.30  17924.86
# 10 2024-08-02  18776.91  18810.42  18269.18  18444.37
# 11 2024-08-01  19549.70  19591.23  18745.52  18904.25
# 12 2024-07-31  18941.01  19446.54  18888.55  19375.05
# 13 2024-07-30  18995.97  19189.35  18674.60  18812.85
# 14 2024-07-29  19102.57  19245.27  18982.54  19076.06
# 15 2024-07-26  18880.77  19157.35  18877.02  19036.14
# 16 2024-07-25  19123.23  19247.25  18740.84  18844.61
# 17 2024-07-24  19644.12  19687.19  19023.66  19055.31
# 18 2024-07-23  19794.97  19933.22  19712.03  19778.69
# 19 2024-07-22  19651.64  19887.26  19554.15  19836.54
# 20 2024-07-19  19769.10  19810.77  19487.95  19542.93

# %%
base.High.mean()
# Out:
# 19142.824285714287

# %% [markdown]
# Analisando tendências entre "maiores altas" e valor de fechamento.

# %%
x = base['High']
y = base['Close']
plt.scatter(x,y)

# %% [markdown]
# Para ajustar um polinômio de 1º grau, demonstrando os coeficientes da reta.

# %%
z = np.polyfit(x,y,1)
p = np.poly1d(z)
plt.plot(x,p(x),"r--")

# %%
import yfinance as yf

# %%
volatilidade_diaria = base['Low'].std()
volatilidade_diaria
# Out:
# 636.3034018805512

# %%
agrupamento2 = base.groupby(base['Data'].dt.month)["High"].sum().plot.bar()
agrupamento2
# Out:
# <Axes: xlabel='Data'>

# %% [markdown]
# Análise ação empresa "Z"

# %%
base2 = pd.read_excel("/Acoes.xlsx")
base2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Data     31 non-null     datetime64[ns]
#  1   Cotacao  31 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 628.0 bytes

# %%
base2.describe()
# Out:
#                                 Data    Cotacao
# count                             31  31.000000
# mean   2024-07-21 14:42:34.838709760   7.270968
# min              2024-07-01 00:00:00   5.730000
# 25%              2024-07-10 12:00:00   6.095000
# 50%              2024-07-22 00:00:00   7.970000
# 75%              2024-08-01 00:00:00   8.145000
# max              2024-08-13 00:00:00   8.560000
# std                              NaN   1.092451

# %%
base2.dropna()
# Out:
#          Data  Cotacao
# 0  2024-07-01     6.13
# 1  2024-07-02     7.97
# 2  2024-08-02     5.94
# 3  2024-07-03     7.99
# 4  2024-07-04     8.15
# 5  2024-07-05     7.99
# 6  2024-08-05     5.81
# 7  2024-08-06     5.77
# 8  2024-08-07     5.73
# 9  2024-07-08     7.87
# 10 2024-08-08     5.83
# 11 2024-07-09     8.02
# 12 2024-08-09     5.95
# 13 2024-07-10     7.92
# 14 2024-07-11     8.00
# 15 2024-07-12     8.06
# 16 2024-08-12     6.06
# 17 2024-08-13     6.25
# 18 2024-07-15     8.17
# 19 2024-07-16     8.14
# 20 2024-07-17     8.55
# 21 2024-07-18     8.40
# 22 2024-07-19     8.53
# 23 2024-07-22     8.56
# 24 2024-07-23     8.29
# 25 2024-07-24     8.11
# 26 2024-07-25     8.28
# 27 2024-07-26     6.33
# 28 2024-07-29     6.05
# 29 2024-07-30     6.33
# 30 2024-07-31     6.22

# %%
base2.Cotacao.median()
# Out:
# 7.97

# %%
volatilidade2 = base2['Cotacao'].std()
volatilidade2
# Out:
# 1.0924509289931814

# %%
np.var(base2.Cotacao)
# Out:
# 1.1549506763787725

# %%
base3 = pd.read_excel("/Upside.xlsx")
base3.head()
# Out:
#           Empresa Ticker Setor      Preço     Preço.1  % Upside  VAR Alvo
# 0             NaN    NaN   NaN  Alvo (R$)  Atual (R$)       NaN       NaN
# 1      BrasilAgro  AGRO3  Agro       29.7       25.75      0.15  0.132997
# 2  Jalles Machado  JALL3  Agro       12.7        6.71      0.89  0.471654
# 3          Raizen  RAIZ4  Agro          6        3.24      0.85  0.460000
# 4    SLC Agricola  SLCE3  Agro       19.6       17.79      0.10  0.092347

# %%
base3.dropna()
# Out:
#            Empresa Ticker           Setor Preço Preço.1  % Upside  VAR Alvo
# 1       BrasilAgro  AGRO3            Agro  29.7   25.75      0.15  0.132997
# 2   Jalles Machado  JALL3            Agro  12.7    6.71      0.89  0.471654
# 3           Raizen  RAIZ4            Agro     6    3.24      0.85  0.460000
# 4     SLC Agricola  SLCE3            Agro  19.6   17.79      0.10  0.092347
# 5     São Martinho  SMTO3            Agro  33.2   29.09      0.14  0.123795
# ..             ...    ...             ...   ...     ...       ...       ...
# 76  PetroReconcavo  RECV3  Petróleo e Gás  27.7   21.06      0.32  0.239711
# 77        Ultrapar  UGPA3  Petróleo e Gás  28.8   23.59      0.22  0.180903
# 78          Unipar  UNIP3  Petróleo e Gás    95   47.65      0.99  0.498421
# 79          Unipar  UNIP6  Petróleo e Gás   105    48.5      1.16  0.538095
# 80   Vibra Energia  VBBR3  Petróleo e Gás  32.7   25.18      0.30  0.229969
#
# [80 rows x 7 columns]

# %%
base3.describe()
# Out:
#         % Upside   VAR Alvo
# count  80.000000  80.000000
# mean    0.378750   0.203375
# std     0.433205   0.239221
# min    -0.420000  -0.719481
# 25%     0.120000   0.104918
# 50%     0.300000   0.228615
# 75%     0.522500   0.340108
# max     2.160000   0.618750
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['% Upside'].plot(kind='hist', bins=20, title='% Upside')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['VAR Alvo'].plot(kind='hist', bins=20, title='VAR Alvo')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='% Upside', y='VAR Alvo', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['% Upside'].plot(kind='line', figsize=(8, 4), title='% Upside')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4['VAR Alvo'].plot(kind='line', figsize=(8, 4), title='VAR Alvo')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# Visualização dos dados estatísticos

# %%
histograma = base3.hist(bins=25)

# %% [markdown]
# Curtose

# %%
base3['% Upside']= pd.to_numeric(base3['% Upside'], errors='coerce')
kurtosis = base3.drop(columns=['Empresa']).kurtosis(numeric_only=True)
kurtosis
# Out:
# % Upside    3.799111
# VAR Alvo    4.863563
# dtype: float64
